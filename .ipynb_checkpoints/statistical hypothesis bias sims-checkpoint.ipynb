# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def generate_hypo_tests(sample_size, true_mean, true_effect, sim_count):
    sim_df = pd.DataFrame(columns = ['rejected','est_effect'])
    for r in range(0,sim_count):
        values = np.random.normal(true_mean,1 ,sample_size)
        values[-1] = values[-1] + true_effect
        
        r_bar = np.mean(values[0:-1] )
        sd = np.std(values[0:-1])
        effect_est = values[-1] - r_bar

        test_stat = np.sqrt((sample_size-1)/sample_size)*effect_est/sd
        rejected = 1*(test_stat > 1.65)
        sim_df.loc[r] = [rejected, effect_est]
    return sim_df

# %% [markdown]
# # Large number of simulations to illustrate bias

# %%
test_sims = generate_hypo_tests(10,1,0,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.0722
# 1.863005401907122

# %%
test_sims = generate_hypo_tests(20,1,0,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.0599
# 1.9462662993699893

# %%
test_sims = generate_hypo_tests(50,1,0,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.0552
# 1.9866893412306619

# %%
test_sims = generate_hypo_tests(10,1,1,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.3058
# 2.1454854720001326

# %%
test_sims = generate_hypo_tests(20,1,1,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.2843
# 2.1956580301065913

# %%
test_sims = generate_hypo_tests(50,1,1,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.2713
# 2.240085983690498

# %%
test_sims = generate_hypo_tests(10,1,2,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.6389
# 2.5732612110834157

# %%
test_sims = generate_hypo_tests(20,1,2,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.6429
# 2.5886306875209493

# %%
test_sims = generate_hypo_tests(50,1,2,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.6305
# 2.5940359662246935

# %%
test_sims = generate_hypo_tests(20,2,0,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.06
# 1.9256966379734721

# %%
test_sims = generate_hypo_tests(20,2,1,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.2767
# 2.2029346234805613

# %%
test_sims = generate_hypo_tests(20,2,4,10000)
print( len(test_sims.query('rejected > 0' ) )/len(test_sims)) 
print(  test_sims.query('rejected > 0')['est_effect'].mean() )
# Out:
# 0.9882
# 4.029938684362172

# %% [markdown]
# # Fix T=10 and mu =1 to plot (Effect Size, Average Payment)

# %%
def hypo_test(values, effect_size):
    r_bar = np.mean(values[0:-1] )
    sd = np.std(values[0:-1])
    effect_est = effect_size + values[-1] - r_bar

    test_stat = np.sqrt((sample_size-1)/sample_size)*effect_est/sd
    rejected = 1*(test_stat > 1.65)
    
    return rejected*effect_est

# %%
plot_sim_df = pd.DataFrame(columns = ['effect'])
plot_sim_df['effect'] = np.linspace(0,3,50)

for sim in range(0,10000):
    values = np.random.normal(1,1,10)
    plot_sim_df[sim] =  plot_sim_df['effect'].apply(lambda s: hypo_test(values,s))

plot_sim_df = plot_sim_df.set_index('effect')
# Out:
#               0         1     2         3         4         5         6     \
# effect
# 0.000000 -0.000000  0.000000  -0.0  0.000000 -0.000000  0.000000 -0.000000
# 0.061224 -0.000000  0.000000  -0.0  0.000000 -0.000000  0.000000  0.000000
# 0.122449 -0.000000  0.000000  -0.0  0.000000 -0.000000  0.000000  0.000000
# 0.183673  0.000000  0.000000  -0.0  0.000000 -0.000000  0.000000  0.000000
# 0.244898  0.000000  0.000000  -0.0  0.000000 -0.000000  0.000000  0.000000
# 0.306122  0.000000  0.000000  -0.0  0.000000 -0.000000  0.000000  0.000000
# 0.367347  0.000000  0.000000  -0.0  0.000000  0.000000  0.000000  0.000000
# 0.428571  0.000000  0.000000  -0.0  0.000000  0.000000  0.000000  0.000000
# 0.489796  0.000000  0.000000  -0.0  0.000000  0.000000  0.000000  0.000000
# 0.551020  0.000000  0.000000  -0.0  0.000000  0.000000  0.000000  0.000000
# 0.612245  0.000000  0.000000  -0.0  0.000000  0.000000  0.000000  0.000000
# 0.673469  0.000000  0.000000  -0.0  0.000000  0.000000  0.000000  0.000000
# 0.734694  0.000000  0.000000  -0.0  1.220680  0.000000  0.000000  0.000000
# 0.795918  0.000000  0.000000  -0.0  1.281904  0.000000  0.000000  0.000000
# 0.857143  0.000000  0.000000  -0.0  1.343129  0.000000  0.000000  0.000000
# 0.918367  0.000000  0.000000  -0.0  1.404353  0.000000  0.000000  0.000000
# 0.979592  0.000000  1.909189  -0.0  1.465578  0.000000  0.000000  0.000000
# 1.040816  0.000000  1.970414  -0.0  1.526802  0.000000  0.000000  0.000000
# 1.102041  0.000000  2.031638  -0.0  1.588027  0.000000  0.000000  0.000000
# 1.163265  0.000000  2.092863  -0.0  1.649251  0.000000  0.000000  0.000000
# 1.224490  0.000000  2.154087  -0.0  1.710476  0.000000  0.000000  0.000000
# 1.285714  0.000000  2.215312  -0.0  1.771700  0.000000  0.000000  0.000000
# 1.346939  1.191317  2.276536  -0.0  1.832925  0.000000  0.000000  0.000000
# 1.408163  1.252541  2.337761  -0.0  1.894149  0.000000  0.000000  0.000000
# 1.469388  1.313766  2.398985  -0.0  1.955374  0.000000  0.000000  0.000000
# 1.530612  1.374990  2.460210  -0.0  2.016598  0.000000  0.000000  1.509751
# 1.591837  1.436215  2.521434  -0.0  2.077823  0.000000  1.989329  1.570976
# 1.653061  1.497439  2.582659  -0.0  2.139047  0.000000  2.050553  1.632200
# 1.714286  1.558664  2.643883  -0.0  2.200272  0.000000  2.111778  1.693424
# 1.775510  1.619888  2.705108  -0.0  2.261496  0.000000  2.173002  1.754649
# 1.836735  1.681113  2.766332  -0.0  2.322721  0.000000  2.234227  1.815873
# 1.897959  1.742337  2.827557  -0.0  2.383945  0.000000  2.295451  1.877098
# 1.959184  1.803561  2.888781   0.0  2.445170  0.000000  2.356676  1.938322
# 2.020408  1.864786  2.950006   0.0  2.506394  0.000000  2.417900  1.999547
# 2.081633  1.926010  3.011230   0.0  2.567619  0.000000  2.479125  2.060771
# 2.142857  1.987235  3.072455   0.0  2.628843  0.000000  2.540349  2.121996
# 2.204082  2.048459  3.133679   0.0  2.690068  0.000000  2.601574  2.183220
# 2.265306  2.109684  3.194904   0.0  2.751292  0.000000  2.662798  2.244445
# 2.326531  2.170908  3.256128   0.0  2.812517  0.000000  2.724023  2.305669
# 2.387755  2.232133  3.317353   0.0  2.873741  0.000000  2.785247  2.366894
# 2.448980  2.293357  3.378577   0.0  2.934966  0.000000  2.846472  2.428118
# 2.510204  2.354582  3.439802   0.0  2.996190  0.000000  2.907696  2.489343
# 2.571429  2.415806  3.501026   0.0  3.057414  0.000000  2.968921  2.550567
# 2.632653  2.477031  3.562251   0.0  3.118639  0.000000  3.030145  2.611792
# 2.693878  2.538255  3.623475   0.0  3.179863  2.337616  3.091370  2.673016
# 2.755102  2.599480  3.684700   0.0  3.241088  2.398840  3.152594  2.734241
# 2.816327  2.660704  3.745924   0.0  3.302312  2.460065  3.213819  2.795465
# 2.877551  2.721929  3.807149   0.0  3.363537  2.521289  3.275043  2.856690
# 2.938776  2.783153  3.868373   0.0  3.424761  2.582514  3.336268  2.917914
# 3.000000  2.844378  3.929598   0.0  3.485986  2.643738  3.397492  2.979139
#
#               7         8         9     ...      9990      9991      9992  \
# effect                                  ...
# 0.000000  0.575909  0.000000 -0.000000  ... -0.000000  0.000000 -0.000000
# 0.061224  0.637133  0.000000  0.000000  ... -0.000000  0.000000 -0.000000
# 0.122449  0.698358  0.000000  0.000000  ... -0.000000  0.000000 -0.000000
# 0.183673  0.759582  0.000000  0.000000  ...  0.000000  0.000000 -0.000000
# 0.244898  0.820807  0.000000  0.000000  ...  0.000000  0.000000 -0.000000
# 0.306122  0.882031  0.000000  0.000000  ...  0.000000  0.000000 -0.000000
# 0.367347  0.943256  0.000000  0.000000  ...  0.000000  0.000000 -0.000000
# 0.428571  1.004480  1.501025  0.000000  ...  0.000000  0.000000 -0.000000
# 0.489796  1.065705  1.562249  0.000000  ...  0.000000  0.000000  0.000000
# 0.551020  1.126929  1.623474  0.000000  ...  0.000000  1.569386  0.000000
# 0.612245  1.188154  1.684698  0.000000  ...  0.000000  1.630611  0.000000
# 0.673469  1.249378  1.745923  0.000000  ...  0.000000  1.691835  0.000000
# 0.734694  1.310603  1.807147  0.000000  ...  0.000000  1.753060  0.000000
# 0.795918  1.371827  1.868372  0.000000  ...  0.000000  1.814284  0.000000
# 0.857143  1.433052  1.929596  0.000000  ...  0.000000  1.875509  0.000000
# 0.918367  1.494276  1.990821  0.000000  ...  0.000000  1.936733  0.000000
# 0.979592  1.555501  2.052045  0.000000  ...  0.000000  1.997958  0.000000
# 1.040816  1.616725  2.113270  0.000000  ...  0.000000  2.059182  0.000000
# 1.102041  1.677950  2.174494  0.000000  ...  0.000000  2.120407  0.000000
# 1.163265  1.739174  2.235719  0.000000  ...  0.000000  2.181631  0.000000
# 1.224490  1.800399  2.296943  0.000000  ...  0.000000  2.242856  0.000000
# 1.285714  1.861623  2.358168  0.000000  ...  0.000000  2.304080  0.000000
# 1.346939  1.922848  2.419392  0.000000  ...  1.204148  2.365305  0.000000
# 1.408163  1.984072  2.480617  0.000000  ...  1.265372  2.426529  0.000000
# 1.469388  2.045297  2.541841  0.000000  ...  1.326597  2.487754  0.000000
# 1.530612  2.106521  2.603066  0.000000  ...  1.387821  2.548978  0.000000
# 1.591837  2.167745  2.664290  0.000000  ...  1.449046  2.610203  0.000000
# 1.653061  2.228970  2.725515  0.000000  ...  1.510270  2.671427  0.000000
# 1.714286  2.290194  2.786739  1.653147  ...  1.571495  2.732652  0.000000
# 1.775510  2.351419  2.847964  1.714372  ...  1.632719  2.793876  0.000000
# 1.836735  2.412643  2.909188  1.775596  ...  1.693944  2.855101  0.000000
# 1.897959  2.473868  2.970413  1.836821  ...  1.755168  2.916325  0.000000
# 1.959184  2.535092  3.031637  1.898045  ...  1.816393  2.977550  0.000000
# 2.020408  2.596317  3.092862  1.959270  ...  1.877617  3.038774  0.000000
# 2.081633  2.657541  3.154086  2.020494  ...  1.938842  3.099999  0.000000
# 2.142857  2.718766  3.215311  2.081719  ...  2.000066  3.161223  0.000000
# 2.204082  2.779990  3.276535  2.142943  ...  2.061291  3.222448  0.000000
# 2.265306  2.841215  3.337760  2.204168  ...  2.122515  3.283672  0.000000
# 2.326531  2.902439  3.398984  2.265392  ...  2.183740  3.344896  0.000000
# 2.387755  2.963664  3.460209  2.326616  ...  2.244964  3.406121  0.000000
# 2.448980  3.024888  3.521433  2.387841  ...  2.306189  3.467345  0.000000
# 2.510204  3.086113  3.582658  2.449065  ...  2.367413  3.528570  2.034377
# 2.571429  3.147337  3.643882  2.510290  ...  2.428638  3.589794  2.095601
# 2.632653  3.208562  3.705106  2.571514  ...  2.489862  3.651019  2.156826
# 2.693878  3.269786  3.766331  2.632739  ...  2.551087  3.712243  2.218050
# 2.755102  3.331011  3.827555  2.693963  ...  2.612311  3.773468  2.279275
# 2.816327  3.392235  3.888780  2.755188  ...  2.673536  3.834692  2.340499
# 2.877551  3.453460  3.950004  2.816412  ...  2.734760  3.895917  2.401724
# 2.938776  3.514684  4.011229  2.877637  ...  2.795985  3.957141  2.462948
# 3.000000  3.575909  4.072453  2.938861  ...  2.857209  4.018366  2.524173
#
#               9993      9994      9995      9996  9997  9998      9999
# effect
# 0.000000 -0.000000 -0.000000  0.000000  0.000000  -0.0  -0.0 -0.000000
# 0.061224 -0.000000 -0.000000  0.000000  0.000000  -0.0  -0.0 -0.000000
# 0.122449 -0.000000 -0.000000  0.000000  0.000000  -0.0  -0.0 -0.000000
# 0.183673 -0.000000 -0.000000  0.000000  0.000000  -0.0  -0.0 -0.000000
# 0.244898 -0.000000 -0.000000  0.000000  0.000000  -0.0  -0.0 -0.000000
# 0.306122 -0.000000 -0.000000  0.000000  0.000000  -0.0  -0.0  0.000000
# 0.367347 -0.000000 -0.000000  1.714443  0.000000  -0.0  -0.0  0.000000
# 0.428571 -0.000000 -0.000000  1.775667  0.000000  -0.0  -0.0  0.000000
# 0.489796 -0.000000 -0.000000  1.836892  0.000000  -0.0  -0.0  0.000000
# 0.551020 -0.000000 -0.000000  1.898116  0.000000  -0.0  -0.0  0.000000
# 0.612245 -0.000000 -0.000000  1.959341  0.000000  -0.0  -0.0  0.000000
# 0.673469 -0.000000 -0.000000  2.020565  0.000000  -0.0  -0.0  0.000000
# 0.734694 -0.000000 -0.000000  2.081790  1.808753  -0.0  -0.0  0.000000
# 0.795918 -0.000000 -0.000000  2.143014  1.869978  -0.0  -0.0  0.000000
# 0.857143 -0.000000 -0.000000  2.204239  1.931202  -0.0  -0.0  0.000000
# 0.918367 -0.000000 -0.000000  2.265463  1.992427  -0.0  -0.0  0.000000
# 0.979592 -0.000000 -0.000000  2.326688  2.053651  -0.0  -0.0  0.000000
# 1.040816  0.000000  0.000000  2.387912  2.114876  -0.0  -0.0  0.000000
# 1.102041  0.000000  0.000000  2.449137  2.176100   0.0  -0.0  0.000000
# 1.163265  0.000000  0.000000  2.510361  2.237325   0.0  -0.0  0.000000
# 1.224490  0.000000  0.000000  2.571586  2.298549   0.0  -0.0  0.000000
# 1.285714  0.000000  0.000000  2.632810  2.359774   0.0  -0.0  0.000000
# 1.346939  0.000000  0.000000  2.694035  2.420998   0.0  -0.0  0.000000
# 1.408163  0.000000  0.000000  2.755259  2.482223   0.0  -0.0  0.000000
# 1.469388  0.000000  0.000000  2.816484  2.543447   0.0  -0.0  0.000000
# 1.530612  0.000000  0.000000  2.877708  2.604672   0.0  -0.0  0.000000
# 1.591837  0.000000  0.000000  2.938933  2.665896   0.0  -0.0  0.000000
# 1.653061  0.000000  0.000000  3.000157  2.727121   0.0  -0.0  0.000000
# 1.714286  0.000000  0.000000  3.061382  2.788345   0.0  -0.0  0.000000
# 1.775510  0.000000  0.000000  3.122606  2.849570   0.0  -0.0  0.000000
# 1.836735  0.000000  0.000000  3.183831  2.910794   0.0  -0.0  0.000000
# 1.897959  0.000000  0.000000  3.245055  2.972019   0.0  -0.0  0.000000
# 1.959184  0.000000  0.000000  3.306280  3.033243   0.0  -0.0  0.000000
# 2.020408  0.000000  0.000000  3.367504  3.094468   0.0  -0.0  0.000000
# 2.081633  0.000000  1.077538  3.428729  3.155692   0.0  -0.0  0.000000
# 2.142857  0.000000  1.138762  3.489953  3.216916   0.0   0.0  1.872113
# 2.204082  0.000000  1.199986  3.551178  3.278141   0.0   0.0  1.933338
# 2.265306  0.000000  1.261211  3.612402  3.339365   0.0   0.0  1.994562
# 2.326531  0.000000  1.322435  3.673627  3.400590   0.0   0.0  2.055787
# 2.387755  0.000000  1.383660  3.734851  3.461814   0.0   0.0  2.117011
# 2.448980  0.000000  1.444884  3.796076  3.523039   0.0   0.0  2.178236
# 2.510204  0.000000  1.506109  3.857300  3.584263   0.0   0.0  2.239460
# 2.571429  0.000000  1.567333  3.918525  3.645488   0.0   0.0  2.300685
# 2.632653  0.000000  1.628558  3.979749  3.706712   0.0   0.0  2.361909
# 2.693878  1.691591  1.689782  4.040973  3.767937   0.0   0.0  2.423134
# 2.755102  1.752815  1.751007  4.102198  3.829161   0.0   0.0  2.484358
# 2.816327  1.814040  1.812231  4.163422  3.890386   0.0   0.0  2.545583
# 2.877551  1.875264  1.873456  4.224647  3.951610   0.0   0.0  2.606807
# 2.938776  1.936489  1.934680  4.285871  4.012835   0.0   0.0  2.668032
# 3.000000  1.997713  1.995905  4.347096  4.074059   0.0   0.0  2.729256
#
# [50 rows x 10000 columns]

# %%
# plot_sim_df = plot_sim_df.set_index(['effect'])

row_sims = plot_sim_df.loc[3.0].copy()
row_sims.sum()/ sum(1*(row_sims > 0))
# Out:
# 3.202508771890911

# %%
average_df = pd.DataFrame(columns = ['effect','avg_rejected']).set_index('effect')

for effect in plot_sim_df.index:
    row_sims = plot_sim_df.loc[effect].copy()
    
    average_df.loc[effect,'avg_rejected'] = row_sims.sum()/ sum(1*(row_sims > 0))

# %%
average_df = average_df.reset_index()
fig, ax = plt.subplots(figsize = (8,6))

average_df['true_effect'] = average_df['effect']
average_df.plot(x='effect', y='avg_rejected', ax = ax, label = 'Average Est. Effect of Rejected Samples', color ='red')
average_df.plot(x='effect',y='true_effect', ax = ax, label = 'True Effect', color = 'black')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-142-2ff50eb48700> in <module>
# ----> 1 average_df = average_df.reset_index()
#       2 fig, ax = plt.subplots(figsize = (8,6))
#       3
#       4 average_df['true_effect'] = average_df['effect']
#       5 average_df.plot(x='effect', y='avg_rejected', ax = ax, label = 'Average Est. Effect of Rejected Samples', color ='red')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# -> 3496         self._data.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3497
#    3498     def assign(self, **kwargs) -> "DataFrame":
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1171         if not allow_duplicates and item in self.items:
#    1172             # Should this be a different kind of error??
# -> 1173             raise ValueError(f"cannot insert {item}, already exists")
#    1174
#    1175         if not isinstance(loc, int):
#
# ValueError: cannot insert level_0, already exists

# %%
plot_sim_df.index
# Out:
# Float64Index([                 0.0, 0.061224489795918366,  0.12244897959183673,
#                0.18367346938775508,  0.24489795918367346,  0.30612244897959184,
#                0.36734693877551017,  0.42857142857142855,   0.4897959183673469,
#                 0.5510204081632653,   0.6122448979591837,    0.673469387755102,
#                 0.7346938775510203,   0.7959183673469388,   0.8571428571428571,
#                 0.9183673469387755,   0.9795918367346939,   1.0408163265306123,
#                 1.1020408163265305,    1.163265306122449,   1.2244897959183674,
#                 1.2857142857142856,    1.346938775510204,   1.4081632653061225,
#                 1.4693877551020407,    1.530612244897959,   1.5918367346938775,
#                  1.653061224489796,   1.7142857142857142,   1.7755102040816326,
#                  1.836734693877551,   1.8979591836734693,   1.9591836734693877,
#                  2.020408163265306,   2.0816326530612246,    2.142857142857143,
#                  2.204081632653061,   2.2653061224489797,    2.326530612244898,
#                  2.387755102040816,   2.4489795918367347,    2.510204081632653,
#                  2.571428571428571,     2.63265306122449,    2.693877551020408,
#                 2.7551020408163263,    2.816326530612245,    2.877551020408163,
#                 2.9387755102040813,                  3.0],
#              dtype='float64', name='effect')
